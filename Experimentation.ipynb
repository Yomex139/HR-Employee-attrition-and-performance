# %% [markdown]
# # importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # importing dataset

# %%
df = pd.read_csv('aug_train.csv.zip')

# %%
df.tail(10)
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 19148         9212   city_21                   0.624     NaN
# 19149          251  city_103                   0.920    Male
# 19150        32313  city_160                   0.920  Female
# 19151        11385  city_149                   0.689    Male
# 19152        29754  city_103                   0.920  Female
# 19153         7386  city_173                   0.878    Male
# 19154        31398  city_103                   0.920    Male
# 19155        24576  city_103                   0.920    Male
# 19156         5756   city_65                   0.802    Male
# 19157        23834   city_67                   0.855     NaN
#
#            relevent_experience enrolled_university education_level  \
# 19148  Has relevent experience       no_enrollment         Masters
# 19149  Has relevent experience       no_enrollment         Masters
# 19150  Has relevent experience       no_enrollment        Graduate
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %%
df['experience'].value_counts()
# Out:
# >20    3286
# 5      1430
# 4      1403
# 3      1354
# 6      1216
# 2      1127
# 7      1028
# 10      985
# 9       980
# 8       802
# 15      686
# 11      664
# 14      586
# 1       549
# <1      522
# 16      508
# 12      494
# 13      399
# 17      342
# 19      304
# 18      280
# 20      148
# Name: experience, dtype: int64

# %%
d = df.replace(to_replace=['>20','<1'],value=[20,0])
d.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target'],
#       dtype='object')

# %%
d.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
d.last_new_job.value_counts()
# Out:
# 1        8040
# >4       3290
# 2        2900
# never    2452
# 4        1029
# 3        1024
# Name: last_new_job, dtype: int64

# %%
d.last_new_job.replace(to_replace=['>4','never'],value=[5,0],inplace=True)
d.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd            5
# ...

# %%
corr = df.corr()
corr
# Out:
#                         enrollee_id  city_development_index  training_hours  \
# enrollee_id                1.000000               -0.040455        0.000998
# city_development_index    -0.040455                1.000000        0.001920
# training_hours             0.000998                0.001920        1.000000
# target                     0.049475               -0.341665       -0.021577
#
#                           target
# enrollee_id             0.049475
# city_development_index -0.341665
# training_hours         -0.021577
# target                  1.000000

# %%
sns.heatmap(corr,cmap='winter',annot=True)
# Out:
# <AxesSubplot:>

# %%
# cond = d.experience == None
# c = d.experience.where(cond,other=d.experience).astype(float).median()
# c

# %%
b = d['experience'].dropna().astype(int).median()

# %%
d['experience'].replace(to_replace=np.nan,value=b,inplace=True)
d['experience'] = pd.to_numeric(d['experience'])

# %%
qqq = d['last_new_job'].dropna().astype(int).median()
d['last_new_job'].fillna(value=9,inplace=True)
d['last_new_job'] = pd.to_numeric(d['last_new_job'])
d['last_new_job']
# Out:
# 0        1
# 1        5
# 2        0
# 3        0
# 4        4
#         ..
# 19153    1
# 19154    4
# 19155    4
# 19156    2
# 19157    1
# Name: last_new_job, Length: 19158, dtype: int64

# %%
d.isna().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                   0
# company_size              5938
# company_type              6140
# last_new_job                 0
# training_hours               0
# target                       0
# dtype: int64

# %%
d.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  last_new_job  \
# 0             STEM        20.0          NaN             NaN             1
# 1             STEM        15.0        50-99         Pvt Ltd             5
# ...

# %%
d_sam = d.copy()
d_sam.head(30)
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 0          8949  city_103                   0.920    Male
# 1         29725   city_40                   0.776    Male
# 2         11561   city_21                   0.624     NaN
# 3         33241  city_115                   0.789     NaN
# 4           666  city_162                   0.767    Male
# 5         21651  city_176                   0.764     NaN
# 6         28806  city_160                   0.920    Male
# 7           402   city_46                   0.762    Male
# 8         27107  city_103                   0.920    Male
# 9           699  city_103                   0.920     NaN
# 10        29452   city_21                   0.624     NaN
# 11        23853  city_103                   0.920    Male
# 12        25619   city_61                   0.913    Male
# 13         5826   city_21                   0.624    Male
# 14         8722   city_21                   0.624     NaN
# ...

# %%
plt.subplots()
